# %%
# Creating a filter
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# Read in the image
image=cv2.imread('images/city_hall.jpg')

# Make a copy of the image
image_copy=np.copy(image)
# Change color to RGB
image_copy=cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)

# %% [markdown]
# ## Convert the image to gray scale

# %%
#convert to grayscale for filtering
gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')

# %% [markdown]
# ## Ceate a Custom Kernel

# %%
sobel_y=np.array([[-1,0,1],
                 [-2,0,2],
                 [-1,0,1]])
filtered_image1=cv2.filter2D(gray,-1,sobel_y)
plt.imshow(filtered_image1,cmap='gray')

# %% [markdown]
# ## create a binary image

# %%
# Create threshold that sets all the filtered pixals to the white
#Above a certain threshold
retval1,binary_image1=cv2.threshold(filtered_image1,100,255,cv2.THRESH_BINARY)
plt.imshow(binary_image1,cmap='gray')

# %%
retval1
# Out:
# 100.0

# %%
sobel_x=np.array([[-1,-2,1],
                 [0,0,0],
                 [1,2,1]])
filtered_image2=cv2.filter2D(gray,-1,sobel_x)
plt.imshow(filtered_image2,cmap='gray')

# %%
retval2,binary_image2=cv2.threshold(filtered_image2,100,255,cv2.THRESH_BINARY)
plt.imshow(binary_image2,cmap='gray')

# %%
# Try out other filters
